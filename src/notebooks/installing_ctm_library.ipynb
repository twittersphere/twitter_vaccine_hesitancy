# %%
# !git clone https://github.com/HuzeyfeAyaz/contextualized-topic-models.git
# Out:
# Cloning into 'contextualized-topic-models'...
# remote: Enumerating objects: 2449, done.
# remote: Counting objects: 100% (600/600), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 2449 (delta 470), reused 439 (delta 402), pack-reused 1849
# Receiving objects: 100% (2449/2449), 32.75 MiB | 42.34 MiB/s, done.
# Resolving deltas: 100% (1559/1559), done.

# %%
# %cd contextualized-topic-models
# Out:
# /content/contextualized-topic-models

# %%
# !git checkout h5py_support
# Out:
# Branch 'h5py_support' set up to track remote branch 'h5py_support' from 'origin'.
# Switched to a new branch 'h5py_support'

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating contextualized_topic_models.egg-info
# writing contextualized_topic_models.egg-info/PKG-INFO
# writing dependency_links to contextualized_topic_models.egg-info/dependency_links.txt
# writing requirements to contextualized_topic_models.egg-info/requires.txt
# writing top-level names to contextualized_topic_models.egg-info/top_level.txt
# writing manifest file 'contextualized_topic_models.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# warning: no files found matching '*.jpg' under directory 'docs'
# warning: no files found matching '*.gif' under directory 'docs'
# adding license file 'LICENSE'
# adding license file 'AUTHORS.rst'
# writing manifest file 'contextualized_topic_models.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/contextualized_topic_models
# copying contextualized_topic_models/__init__.py -> build/lib/contextualized_topic_models
# copying contextualized_topic_models/contextualized_topic_models.py -> build/lib/contextualized_topic_models
# creating build/lib/contextualized_topic_models/datasets
# copying contextualized_topic_models/datasets/__init__.py -> build/lib/contextualized_topic_models/datasets
# copying contextualized_topic_models/datasets/dataset.py -> build/lib/contextualized_topic_models/datasets
# creating build/lib/contextualized_topic_models/models
# copying contextualized_topic_models/models/__init__.py -> build/lib/contextualized_topic_models/models
# copying contextualized_topic_models/models/kitty_classifier.py -> build/lib/contextualized_topic_models/models
# copying contextualized_topic_models/models/ctm.py -> build/lib/contextualized_topic_models/models
# creating build/lib/contextualized_topic_models/utils
# copying contextualized_topic_models/utils/__init__.py -> build/lib/contextualized_topic_models/utils
# copying contextualized_topic_models/utils/data_preparation.py -> build/lib/contextualized_topic_models/utils
# copying contextualized_topic_models/utils/preprocessing.py -> build/lib/contextualized_topic_models/utils
# creating build/lib/contextualized_topic_models/evaluation
# copying contextualized_topic_models/evaluation/measures.py -> build/lib/contextualized_topic_models/evaluation
# copying contextualized_topic_models/evaluation/__init__.py -> build/lib/contextualized_topic_models/evaluation
# creating build/lib/contextualized_topic_models/networks
# copying contextualized_topic_models/networks/__init__.py -> build/lib/contextualized_topic_models/networks
# copying contextualized_topic_models/networks/inference_network.py -> build/lib/contextualized_topic_models/networks
# copying contextualized_topic_models/networks/decoding_network.py -> build/lib/contextualized_topic_models/networks
# creating build/lib/contextualized_topic_models/utils/early_stopping
# copying contextualized_topic_models/utils/early_stopping/__init__.py -> build/lib/contextualized_topic_models/utils/early_stopping
# copying contextualized_topic_models/utils/early_stopping/early_stopping.py -> build/lib/contextualized_topic_models/utils/early_stopping
# creating build/lib/contextualized_topic_models/evaluation/rbo
# copying contextualized_topic_models/evaluation/rbo/__init__.py -> build/lib/contextualized_topic_models/evaluation/rbo
# copying contextualized_topic_models/evaluation/rbo/rbo.py -> build/lib/contextualized_topic_models/evaluation/rbo
# creating build/lib/contextualized_topic_models/data
# copying contextualized_topic_models/data/sample_text_document -> build/lib/contextualized_topic_models/data
# creating build/lib/contextualized_topic_models/data/custom_embeddings
# copying contextualized_topic_models/data/custom_embeddings/sample_embeddings.npy -> build/lib/contextualized_topic_models/data/custom_embeddings
# copying contextualized_topic_models/data/custom_embeddings/sample_text.txt -> build/lib/contextualized_topic_models/data/custom_embeddings
# creating build/lib/contextualized_topic_models/data/gnews
# copying contextualized_topic_models/data/gnews/GoogleNews.txt -> build/lib/contextualized_topic_models/data/gnews
# copying contextualized_topic_models/data/gnews/GoogleNews_LABEL.txt -> build/lib/contextualized_topic_models/data/gnews
# copying contextualized_topic_models/data/gnews/bert_embeddings_gnews -> build/lib/contextualized_topic_models/data/gnews
# copying contextualized_topic_models/data/gnews/train.txt.pkl -> build/lib/contextualized_topic_models/data/gnews
# copying contextualized_topic_models/data/gnews/vocab.pkl -> build/lib/contextualized_topic_models/data/gnews
# copying contextualized_topic_models/utils/early_stopping/CODE_OF_CONDUCT.md -> build/lib/contextualized_topic_models/utils/early_stopping
# copying contextualized_topic_models/utils/early_stopping/LICENSE -> build/lib/contextualized_topic_models/utils/early_stopping
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/datasets
# copying build/lib/contextualized_topic_models/datasets/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/datasets
# copying build/lib/contextualized_topic_models/datasets/dataset.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/datasets
# copying build/lib/contextualized_topic_models/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models
# copying build/lib/contextualized_topic_models/contextualized_topic_models.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/models
# copying build/lib/contextualized_topic_models/models/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/models
# copying build/lib/contextualized_topic_models/models/kitty_classifier.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/models
# copying build/lib/contextualized_topic_models/models/ctm.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/models
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/utils
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping
# copying build/lib/contextualized_topic_models/utils/early_stopping/CODE_OF_CONDUCT.md -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping
# copying build/lib/contextualized_topic_models/utils/early_stopping/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping
# copying build/lib/contextualized_topic_models/utils/early_stopping/early_stopping.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping
# copying build/lib/contextualized_topic_models/utils/early_stopping/LICENSE -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping
# copying build/lib/contextualized_topic_models/utils/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils
# copying build/lib/contextualized_topic_models/utils/data_preparation.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils
# copying build/lib/contextualized_topic_models/utils/preprocessing.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/utils
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/data
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/data/custom_embeddings
# copying build/lib/contextualized_topic_models/data/custom_embeddings/sample_embeddings.npy -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/custom_embeddings
# copying build/lib/contextualized_topic_models/data/custom_embeddings/sample_text.txt -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/custom_embeddings
# copying build/lib/contextualized_topic_models/data/sample_text_document -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/data/gnews
# copying build/lib/contextualized_topic_models/data/gnews/bert_embeddings_gnews -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/gnews
# copying build/lib/contextualized_topic_models/data/gnews/vocab.pkl -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/gnews
# copying build/lib/contextualized_topic_models/data/gnews/train.txt.pkl -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/gnews
# copying build/lib/contextualized_topic_models/data/gnews/GoogleNews.txt -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/gnews
# copying build/lib/contextualized_topic_models/data/gnews/GoogleNews_LABEL.txt -> build/bdist.linux-x86_64/egg/contextualized_topic_models/data/gnews
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation
# copying build/lib/contextualized_topic_models/evaluation/measures.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation
# copying build/lib/contextualized_topic_models/evaluation/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/rbo
# copying build/lib/contextualized_topic_models/evaluation/rbo/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/rbo
# copying build/lib/contextualized_topic_models/evaluation/rbo/rbo.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/rbo
# creating build/bdist.linux-x86_64/egg/contextualized_topic_models/networks
# copying build/lib/contextualized_topic_models/networks/__init__.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/networks
# copying build/lib/contextualized_topic_models/networks/inference_network.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/networks
# copying build/lib/contextualized_topic_models/networks/decoding_network.py -> build/bdist.linux-x86_64/egg/contextualized_topic_models/networks
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/datasets/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/datasets/dataset.py to dataset.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/contextualized_topic_models.py to contextualized_topic_models.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/models/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/models/kitty_classifier.py to kitty_classifier.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/models/ctm.py to ctm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/early_stopping/early_stopping.py to early_stopping.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/data_preparation.py to data_preparation.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/utils/preprocessing.py to preprocessing.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/measures.py to measures.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/rbo/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/evaluation/rbo/rbo.py to rbo.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/networks/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/networks/inference_network.py to inference_network.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/contextualized_topic_models/networks/decoding_network.py to decoding_network.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying contextualized_topic_models.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying contextualized_topic_models.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying contextualized_topic_models.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying contextualized_topic_models.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying contextualized_topic_models.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying contextualized_topic_models.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/contextualized_topic_models-2.3.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing contextualized_topic_models-2.3.0-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/contextualized_topic_models-2.3.0-py3.7.egg
# Extracting contextualized_topic_models-2.3.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding contextualized-topic-models 2.3.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/contextualized_topic_models-2.3.0-py3.7.egg
# Processing dependencies for contextualized-topic-models==2.3.0
# Searching for ipython==7.16.3
# Reading https://pypi.org/simple/ipython/
# Downloading https://files.pythonhosted.org/packages/53/09/958a4802489d28b2484114ee6414c7502ef57de6f2dbc9095b718640060c/ipython-7.16.3-py3-none-any.whl#sha256=c0427ed8bc33ac481faf9d3acf7e84e0010cdaada945e0badd1e2e74cc075833
# Best match: ipython 7.16.3
# Processing ipython-7.16.3-py3-none-any.whl
# Installing ipython-7.16.3-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding ipython 7.16.3 to easy-install.pth file
# Installing iptest script to /usr/local/bin
# Installing iptest3 script to /usr/local/bin
# Installing ipython script to /usr/local/bin
# Installing ipython3 script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/ipython-7.16.3-py3.7.egg
# Searching for ipywidgets==7.5.1
# Reading https://pypi.org/simple/ipywidgets/
# Downloading https://files.pythonhosted.org/packages/56/a0/dbcf5881bb2f51e8db678211907f16ea0a182b232c591a6d6f276985ca95/ipywidgets-7.5.1-py2.py3-none-any.whl#sha256=13ffeca438e0c0f91ae583dc22f50379b9d6b28390ac7be8b757140e9a771516
# Best match: ipywidgets 7.5.1
# Processing ipywidgets-7.5.1-py2.py3-none-any.whl
# Installing ipywidgets-7.5.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding ipywidgets 7.5.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/ipywidgets-7.5.1-py3.7.egg
# Searching for wordcloud>=1.8.1
# Reading https://pypi.org/simple/wordcloud/
# Downloading https://files.pythonhosted.org/packages/05/1e/ff1052b62f233243f3d088d0815bf5ca0ed31f1aa64ae060dd78f3e1d636/wordcloud-1.8.2.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=43a71a15ac8f721f425d1030633f26a8037ddb767fe9bb45647fe5ed94b92eda
# Best match: wordcloud 1.8.2.2
# Processing wordcloud-1.8.2.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing wordcloud-1.8.2.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding wordcloud 1.8.2.2 to easy-install.pth file
# Installing wordcloud_cli script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/wordcloud-1.8.2.2-py3.7-linux-x86_64.egg
# Searching for gensim>=3.8.3
# Reading https://pypi.org/simple/gensim/
# Downloading https://files.pythonhosted.org/packages/1c/22/fe12d98526b54890ca0338f8bc8061e1050181b9db281b783f389367f531/gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl#sha256=cccf80d032dac1d6be8de06a8c8ed763496acda8c37e5c9a9d19c712f16d8fd3
# Best match: gensim 4.2.0
# Processing gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Installing gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding gensim 4.2.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/gensim-4.2.0-py3.7-linux-x86_64.egg
# Searching for prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
# Reading https://pypi.org/simple/prompt-toolkit/
# Downloading https://files.pythonhosted.org/packages/b0/8f/09a88160539a1164de562809f8b1d0a36dc1f9d8c6473f4b71ebed17b953/prompt_toolkit-3.0.30-py3-none-any.whl#sha256=d8916d3f62a7b67ab353a952ce4ced6a1d2587dfe9ef8ebc30dd7c386751f289
# Best match: prompt-toolkit 3.0.30
# Processing prompt_toolkit-3.0.30-py3-none-any.whl
# Installing prompt_toolkit-3.0.30-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding prompt-toolkit 3.0.30 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/prompt_toolkit-3.0.30-py3.7.egg
# Searching for jedi<=0.17.2,>=0.10
# Reading https://pypi.org/simple/jedi/
# Downloading https://files.pythonhosted.org/packages/c3/d4/36136b18daae06ad798966735f6c3fb96869c1be9f8245d2a8f556e40c36/jedi-0.17.2-py2.py3-none-any.whl#sha256=98cc583fa0f2f8304968199b01b6b4b94f469a1f4a74c1560506ca2a211378b5
# Best match: jedi 0.17.2
# Processing jedi-0.17.2-py2.py3-none-any.whl
# Installing jedi-0.17.2-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding jedi 0.17.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/jedi-0.17.2-py3.7.egg
# Searching for widgetsnbextension~=3.5.0
# Reading https://pypi.org/simple/widgetsnbextension/
# Downloading https://files.pythonhosted.org/packages/d7/31/7c1107fa30c621cd1d36410e9bbab86f6a518dc208aaec01f02ac6d5c2d2/widgetsnbextension-3.5.2-py2.py3-none-any.whl#sha256=763a9fdc836d141fa080005a886d63f66f73d56dba1fb5961afc239c77708569
# Best match: widgetsnbextension 3.5.2
# Processing widgetsnbextension-3.5.2-py2.py3-none-any.whl
# Installing widgetsnbextension-3.5.2-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding widgetsnbextension 3.5.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/widgetsnbextension-3.5.2-py3.7.egg
# Searching for parso<0.8.0,>=0.7.0
# Reading https://pypi.org/simple/parso/
# Downloading https://files.pythonhosted.org/packages/93/d1/e635bdde32890db5aeb2ffbde17e74f68986305a4466b0aa373b861e3f00/parso-0.7.1-py2.py3-none-any.whl#sha256=97218d9159b2520ff45eb78028ba8b50d2bc61dcc062a9682666f2dc4bd331ea
# Best match: parso 0.7.1
# Processing parso-0.7.1-py2.py3-none-any.whl
# Installing parso-0.7.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding parso 0.7.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/parso-0.7.1-py3.7.egg
# Searching for scipy==1.4.1
# Best match: scipy 1.4.1
# Adding scipy 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tqdm==4.64.0
# Best match: tqdm 4.64.0
# Adding tqdm 4.64.0 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for matplotlib==3.2.2
# Best match: matplotlib 3.2.2
# Adding matplotlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sentence-transformers==2.2.2
# Best match: sentence-transformers 2.2.2
# Adding sentence-transformers 2.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torch==1.11.0+cu113
# Best match: torch 1.11.0+cu113
# Adding torch 1.11.0+cu113 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torchvision==0.12.0+cu113
# Best match: torchvision 0.12.0+cu113
# Adding torchvision 0.12.0+cu113 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.21.6
# Best match: numpy 1.21.6
# Adding numpy 1.21.6 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for traitlets==5.1.1
# Best match: traitlets 5.1.1
# Adding traitlets 5.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for setuptools==57.4.0
# Best match: setuptools 57.4.0
# Adding setuptools 57.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Pygments==2.6.1
# Best match: Pygments 2.6.1
# Adding Pygments 2.6.1 to easy-install.pth file
# Installing pygmentize script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pickleshare==0.7.5
# Best match: pickleshare 0.7.5
# Adding pickleshare 0.7.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pexpect==4.8.0
# Best match: pexpect 4.8.0
# Adding pexpect 4.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for decorator==4.4.2
# Best match: decorator 4.4.2
# Adding decorator 4.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for backcall==0.2.0
# Best match: backcall 0.2.0
# Adding backcall 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for nbformat==5.4.0
# Best match: nbformat 5.4.0
# Adding nbformat 5.4.0 to easy-install.pth file
# Installing jupyter-trust script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for ipykernel==4.10.1
# Best match: ipykernel 4.10.1
# Adding ipykernel 4.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for kiwisolver==1.4.3
# Best match: kiwisolver 1.4.3
# Adding kiwisolver 1.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Pillow==7.1.2
# Best match: Pillow 7.1.2
# Adding Pillow 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for scikit-learn==1.0.2
# Best match: scikit-learn 1.0.2
# Adding scikit-learn 1.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for nltk==3.7
# Best match: nltk 3.7
# Adding nltk 3.7 to easy-install.pth file
# Installing nltk script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for transformers==4.20.1
# Best match: transformers 4.20.1
# Adding transformers 4.20.1 to easy-install.pth file
# Installing transformers-cli script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sentencepiece==0.1.96
# Best match: sentencepiece 0.1.96
# Adding sentencepiece 0.1.96 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for huggingface-hub==0.8.1
# Best match: huggingface-hub 0.8.1
# Adding huggingface-hub 0.8.1 to easy-install.pth file
# Installing huggingface-cli script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for smart-open==5.2.1
# Best match: smart-open 5.2.1
# Adding smart-open 5.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==4.1.1
# Best match: typing-extensions 4.1.1
# Adding typing-extensions 4.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for requests==2.23.0
# Best match: requests 2.23.0
# Adding requests 2.23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for wcwidth==0.2.5
# Best match: wcwidth 0.2.5
# Adding wcwidth 0.2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for ptyprocess==0.7.0
# Best match: ptyprocess 0.7.0
# Adding ptyprocess 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for notebook==5.3.1
# Best match: notebook 5.3.1
# Adding notebook 5.3.1 to easy-install.pth file
# Installing jupyter-bundlerextension script to /usr/local/bin
# Installing jupyter-nbextension script to /usr/local/bin
# Installing jupyter-notebook script to /usr/local/bin
# Installing jupyter-serverextension script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for jupyter-core==4.10.0
# Best match: jupyter-core 4.10.0
# Adding jupyter-core 4.10.0 to easy-install.pth file
# Installing jupyter script to /usr/local/bin
# Installing jupyter-migrate script to /usr/local/bin
# Installing jupyter-troubleshoot script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for jsonschema==4.3.3
# Best match: jsonschema 4.3.3
# Adding jsonschema 4.3.3 to easy-install.pth file
# Installing jsonschema script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for fastjsonschema==2.15.3
# Best match: fastjsonschema 2.15.3
# Adding fastjsonschema 2.15.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tornado==5.1.1
# Best match: tornado 5.1.1
# Adding tornado 5.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for jupyter-client==5.3.5
# Best match: jupyter-client 5.3.5
# Adding jupyter-client 5.3.5 to easy-install.pth file
# Installing jupyter-kernel script to /usr/local/bin
# Installing jupyter-kernelspec script to /usr/local/bin
# Installing jupyter-run script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for joblib==1.1.0
# Best match: joblib 1.1.0
# Adding joblib 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for threadpoolctl==3.1.0
# Best match: threadpoolctl 3.1.0
# Adding threadpoolctl 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for click==7.1.2
# Best match: click 7.1.2
# Adding click 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for regex==2022.6.2
# Best match: regex 2022.6.2
# Adding regex 2022.6.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for filelock==3.7.1
# Best match: filelock 3.7.1
# Adding filelock 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for importlib-metadata==4.11.4
# Best match: importlib-metadata 4.11.4
# Adding importlib-metadata 4.11.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tokenizers==0.12.1
# Best match: tokenizers 0.12.1
# Adding tokenizers 0.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for packaging==21.3
# Best match: packaging 21.3
# Adding packaging 21.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for PyYAML==6.0
# Best match: PyYAML 6.0
# Adding PyYAML 6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2022.6.15
# Best match: certifi 2022.6.15
# Adding certifi 2022.6.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Send2Trash==1.8.0
# Best match: Send2Trash 1.8.0
# Adding Send2Trash 1.8.0 to easy-install.pth file
# Installing send2trash script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for terminado==0.13.3
# Best match: terminado 0.13.3
# Adding terminado 0.13.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for ipython-genutils==0.2.0
# Best match: ipython-genutils 0.2.0
# Adding ipython-genutils 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Jinja2==2.11.3
# Best match: Jinja2 2.11.3
# Adding Jinja2 2.11.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for nbconvert==5.6.1
# Best match: nbconvert 5.6.1
# Adding nbconvert 5.6.1 to easy-install.pth file
# Installing jupyter-nbconvert script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for attrs==21.4.0
# Best match: attrs 21.4.0
# Adding attrs 21.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for importlib-resources==5.7.1
# Best match: importlib-resources 5.7.1
# Adding importlib-resources 5.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyrsistent==0.18.1
# Best match: pyrsistent 0.18.1
# Adding pyrsistent 0.18.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyzmq==23.1.0
# Best match: pyzmq 23.1.0
# Adding pyzmq 23.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for zipp==3.8.0
# Best match: zipp 3.8.0
# Adding zipp 3.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for MarkupSafe==2.0.1
# Best match: MarkupSafe 2.0.1
# Adding MarkupSafe 2.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for entrypoints==0.4
# Best match: entrypoints 0.4
# Adding entrypoints 0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for testpath==0.6.0
# Best match: testpath 0.6.0
# Adding testpath 0.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for mistune==0.8.4
# Best match: mistune 0.8.4
# Adding mistune 0.8.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for defusedxml==0.7.1
# Best match: defusedxml 0.7.1
# Adding defusedxml 0.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pandocfilters==1.5.0
# Best match: pandocfilters 1.5.0
# Adding pandocfilters 1.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for bleach==5.0.0
# Best match: bleach 5.0.0
# Adding bleach 5.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for webencodings==0.5.1
# Best match: webencodings 0.5.1
# Adding webencodings 0.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for contextualized-topic-models==2.3.0

# %%
import os
os._exit(00)
